# %%
from itertools import chain
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('VLagun_Total_Years_depth.csv')
df = df.iloc[:, 0:57]
test_size = 0.3
dftrain, dftest = train_test_split(df, test_size=test_size, random_state=0)

dftrain.head()
# Out:
#        PSU     O2  temp.     SS   SRP   DOP     PP   NH4N   NO3N    DON  ...  \
# 2    3.721   9.63   17.5  62.00  11.7  13.0  117.6  0.036  0.021  0.727  ...
# 124  2.600  12.28   11.3  40.00   5.7   8.1   75.6  0.020  0.023  0.483  ...
# 43   2.400  12.11   10.9  29.00   4.5   9.3   77.8  0.028  0.027  0.575  ...
# 100  3.342  11.15   20.0  68.75  10.9  51.0  107.9  0.012  0.029  0.543  ...
# 10   4.083  10.46   20.5  53.75  11.7  16.6  161.3  0.002  0.043  0.536  ...
#
#      Keratella cochlearis cochlearis  Keratella cochlearis f.tecta  \
# 2                              0.012                         0.004
# 124                            0.000                         0.006
# 43                             0.000                         0.010
# 100                            0.040                         0.004
# 10                             1.923                         0.036
#
#      Keratella quadrata  Polyarthra vulgaris  Polyarthra platyptera  \
# 2                 0.000                0.000                  0.000
# 124               0.011                0.000                  0.000
# 43                0.015                0.000                  0.000
# 100               0.000                0.000                  0.000
# 10                0.018                0.149                  0.437
#
#      Pompholyx sp.  Synchaeta sp.  Trichocerca pusilla  Trichocerca similis  \
# 2              0.0            0.0                0.000                  0.0
# 124            0.0            0.0                0.000                  0.0
# 43             0.0            0.0                0.000                  0.0
# 100            0.0            0.0                0.000                  0.0
# 10             0.0            0.0                0.002                  0.0
#
#      Depth
# 2      3.0
# 124    3.0
# 43     3.5
# 100    2.0
# 10     3.5
#
# [5 rows x 57 columns]

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108 entries, 2 to 47
# Data columns (total 57 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   PSU                                     108 non-null    float64
#  1   O2                                      108 non-null    float64
#  2   temp.                                   108 non-null    float64
#  3   SS                                      108 non-null    float64
#  4   SRP                                     108 non-null    float64
#  5   DOP                                     108 non-null    float64
#  6   PP                                      108 non-null    float64
#  7   NH4N                                    108 non-null    float64
#  8   NO3N                                    108 non-null    float64
#  9   DON                                     108 non-null    float64
#  10  PN                                      108 non-null    float64
#  11  TN/TP                                   108 non-null    float64
#  12  Fe                                      108 non-null    float64
#  13  SiO4Si                                  108 non-null    float64
#  14  DOC                                     108 non-null    float64
#  15  TPOC                                    108 non-null    float64
#  16  Windspeedinsitu                         108 non-null    float64
#  17  DINtoDIP                                108 non-null    float64
#  18  Cyanobacteria                           108 non-null    float64
#  19  Chlorophyceae                           108 non-null    float64
#  20  Euglenophyceae                          108 non-null    float64
#  21  Diatomophyceae                          108 non-null    float64
#  22  Flagellata                              108 non-null    float64
#  23  Dinoflagellata                          108 non-null    float64
#  24  Cryptophytes                            108 non-null    float64
#  25  picophytoplankton                       108 non-null    float64
#  26  Bosmina longirostris                    108 non-null    float64
#  27  Ceriodaphnia sp.                        108 non-null    float64
#  28  Diaphanosoma brachyurum                 108 non-null    float64
#  29  Leptodora kindtii                       108 non-null    float64
#  30  Acartia longiremis                      108 non-null    float64
#  31  Acartia tonsa                           108 non-null    float64
#  32  Eurytemora affinis                      108 non-null    float64
#  33  Cyclops sp.                             108 non-null    float64
#  34  Nauplii Cyclopoida                      108 non-null    float64
#  35  Nauplii Calanoida                       108 non-null    float64
#  36  Thermocyclops oithonoides               108 non-null    float64
#  37  Eurytemora lacustris                    108 non-null    float64
#  38  Ascomorpha saltans                      108 non-null    float64
#  39  Asplanchna priodonta                    108 non-null    float64
#  40  Brachionus angularis                    108 non-null    float64
#  41  Brachionus calyciflorus calyciflorus    108 non-null    float64
#  42  Brachionus calyciflorus f.amphiceros    108 non-null    float64
#  43  Brachionus calyciflorus spinosus        108 non-null    float64
#  44  Brachionus urceolaris                   108 non-null    float64
#  45  Brachionus calyciflorus f.anureiformis  108 non-null    float64
#  46  Filinia longiseta                       108 non-null    float64
#  47  Keratella cochlearis cochlearis         108 non-null    float64
#  48  Keratella cochlearis f.tecta            108 non-null    float64
#  49  Keratella quadrata                      108 non-null    float64
#  50  Polyarthra vulgaris                     108 non-null    float64
#  51  Polyarthra platyptera                   108 non-null    float64
#  52  Pompholyx sp.                           108 non-null    float64
#  53  Synchaeta sp.                           108 non-null    float64
#  54  Trichocerca pusilla                     108 non-null    float64
#  55  Trichocerca similis                     108 non-null    float64
#  56  Depth                                   108 non-null    float64
# dtypes: float64(57)
# memory usage: 48.9 KB

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(dftrain.corr(), fmt='.2f', cmap='YlGnBu')
# Out:
# <Axes: >

# %%
dftrain.describe()
# Out:
#               PSU          O2       temp.          SS         SRP         DOP  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000  108.000000
# mean     3.307046   10.158056   17.350926   88.412778   14.171296   22.078704
# std      0.764205    1.065294    3.220451   37.109523   12.065453   18.740371
# min      1.500000    8.420000   10.600000   29.000000    1.100000    0.800000
# 25%      2.700000    9.340000   16.200000   61.187500    7.375000    8.900000
# 50%      3.342000    9.940000   18.000000   80.000000   11.700000   15.850000
# 75%      3.870000   10.900000   20.100000  112.500000   15.975000   30.300000
# max      4.500000   12.850000   20.700000  217.500000   88.200000   83.600000
#
#                PP        NH4N        NO3N         DON  ...  \
# count  108.000000  108.000000  108.000000  108.000000  ...
# mean   135.981481    0.029963    0.037315    0.560352  ...
# std     50.191709    0.018803    0.021279    0.172777  ...
# min     20.900000    0.002000    0.007000    0.022000  ...
# 25%     99.950000    0.019000    0.024000    0.487750  ...
# 50%    134.650000    0.026500    0.032000    0.563000  ...
# 75%    171.100000    0.036000    0.045500    0.680500  ...
# max    285.100000    0.106000    0.142000    0.975000  ...
#
#        Keratella cochlearis cochlearis  Keratella cochlearis f.tecta  \
# count                       108.000000                    108.000000
# mean                          0.299259                      0.021657
# std                           0.825955                      0.050094
# min                           0.000000                      0.000000
# 25%                           0.002000                      0.001000
# 50%                           0.016000                      0.003500
# 75%                           0.044250                      0.009000
# max                           5.311000                      0.271000
#
#        Keratella quadrata  Polyarthra vulgaris  Polyarthra platyptera  \
# count          108.000000           108.000000             108.000000
# mean             0.021241             0.007407               0.011296
# std              0.084691             0.026193               0.052932
# min              0.000000             0.000000               0.000000
# 25%              0.000000             0.000000               0.000000
# 50%              0.000000             0.000000               0.000000
# 75%              0.003500             0.000000               0.000000
# max              0.804000             0.167000               0.437000
#
#        Pompholyx sp.  Synchaeta sp.  Trichocerca pusilla  Trichocerca similis  \
# count     108.000000     108.000000           108.000000           108.000000
# mean        0.000741       0.002333             0.000546             0.000639
# std         0.002930       0.013138             0.001748             0.002189
# min         0.000000       0.000000             0.000000             0.000000
# 25%         0.000000       0.000000             0.000000             0.000000
# 50%         0.000000       0.000000             0.000000             0.000000
# 75%         0.000000       0.000000             0.000000             0.000000
# max         0.017000       0.118000             0.011000             0.013000
#
#             Depth
# count  108.000000
# mean     3.050926
# std      0.546612
# min      1.500000
# 25%      3.000000
# 50%      3.000000
# 75%      3.500000
# max      4.000000
#
# [8 rows x 57 columns]

# %%
dftrain.columns
# Out:
# Index(['PSU', 'O2', 'temp.', 'SS', 'SRP', 'DOP', 'PP', 'NH4N', 'NO3N', 'DON',
#        'PN', 'TN/TP', 'Fe', 'SiO4Si', 'DOC', 'TPOC', 'Windspeedinsitu',
#        'DINtoDIP', 'Cyanobacteria', 'Chlorophyceae', 'Euglenophyceae',
#        'Diatomophyceae', 'Flagellata   ', 'Dinoflagellata ', 'Cryptophytes',
#        'picophytoplankton', 'Bosmina longirostris', 'Ceriodaphnia sp.',
#        'Diaphanosoma brachyurum ', 'Leptodora kindtii', 'Acartia longiremis',
#        'Acartia tonsa', 'Eurytemora affinis', 'Cyclops sp. ',
#        'Nauplii Cyclopoida', 'Nauplii Calanoida', 'Thermocyclops oithonoides',
#        'Eurytemora lacustris', 'Ascomorpha saltans', 'Asplanchna priodonta',
#        'Brachionus angularis', 'Brachionus calyciflorus calyciflorus',
#        'Brachionus calyciflorus f.amphiceros',
#        'Brachionus calyciflorus spinosus', 'Brachionus urceolaris',
#        'Brachionus calyciflorus f.anureiformis', 'Filinia longiseta',
#        'Keratella cochlearis cochlearis', 'Keratella cochlearis f.tecta',
#        'Keratella quadrata', 'Polyarthra vulgaris', 'Polyarthra platyptera',
#        'Pompholyx sp.', 'Synchaeta sp.', 'Trichocerca pusilla',
#        'Trichocerca similis', 'Depth'],
#       dtype='object')

# %%
for i in dftrain.columns:
    sns.FacetGrid(dftrain, hue='Depth', height=5).map(sns.distplot, i)
    plt.legend()

# %%
class ChiSquare:
  def __init__(self, dataframe):
    self.df = dataframe
    self.p = None  # p-value
    self.chi2 = None  # chi test statistic
    self.dof = None

    self.df_observed = None
    self.df_expected = None

  def _print_chisquare_result(self, col_x, alpha):
    if self.p < alpha:
      result = f'{col_x} is IMPORTANT for Prediction.'
    else:
      result = f'{col_x} is NOT an important predictor. Discard {col_x} from model.'
    print(result)

  def test_independence(self, col_x, col_y, alpha=0.25):
    x = self.df[col_x].astype(str)
    y = self.df[col_y].astype(str)
    self.df_observed = pd.crosstab(y, x)
    self.chi2, self.p, self.dof, expected = stats.chi2_contingency(self.df_observed.values)
    self.df_expected = pd.DataFrame(expected, columns=self.df_observed.columns, index=self.df_observed.index)
    self._print_chisquare_result(col_x, alpha)


cT = ChiSquare(dftrain)

for column_name in dftrain.columns[:-1]:
  cT.test_independence(col_x=column_name, col_y=dftrain.columns[-1])
# Out:
# PSU is NOT an important predictor. Discard PSU from model.
# O2 is NOT an important predictor. Discard O2 from model.
# temp. is NOT an important predictor. Discard temp. from model.
# SS is IMPORTANT for Prediction.
# SRP is NOT an important predictor. Discard SRP from model.
# DOP is IMPORTANT for Prediction.
# PP is NOT an important predictor. Discard PP from model.
# NH4N is IMPORTANT for Prediction.
# NO3N is NOT an important predictor. Discard NO3N from model.
# DON is NOT an important predictor. Discard DON from model.
# PN is NOT an important predictor. Discard PN from model.
# TN/TP is NOT an important predictor. Discard TN/TP from model.
# Fe is NOT an important predictor. Discard Fe from model.
# SiO4Si is NOT an important predictor. Discard SiO4Si from model.
# DOC is NOT an important predictor. Discard DOC from model.
# TPOC is NOT an important predictor. Discard TPOC from model.
# Windspeedinsitu is NOT an important predictor. Discard Windspeedinsitu from model.
# DINtoDIP is NOT an important predictor. Discard DINtoDIP from model.
# Cyanobacteria is NOT an important predictor. Discard Cyanobacteria from model.
# Chlorophyceae is NOT an important predictor. Discard Chlorophyceae from model.
# Euglenophyceae is NOT an important predictor. Discard Euglenophyceae from model.
# Diatomophyceae is NOT an important predictor. Discard Diatomophyceae from model.
# Flagellata    is NOT an important predictor. Discard Flagellata    from model.
# Dinoflagellata  is NOT an important predictor. Discard Dinoflagellata  from model.
# Cryptophytes is NOT an important predictor. Discard Cryptophytes from model.
# picophytoplankton is IMPORTANT for Prediction.
# Bosmina longirostris is NOT an important predictor. Discard Bosmina longirostris from model.
# Ceriodaphnia sp. is NOT an important predictor. Discard Ceriodaphnia sp. from model.
# Diaphanosoma brachyurum  is IMPORTANT for Prediction.
# Leptodora kindtii is NOT an important predictor. Discard Leptodora kindtii from model.
# Acartia longiremis is NOT an important predictor. Discard Acartia longiremis from model.
# Acartia tonsa is NOT an important predictor. Discard Acartia tonsa from model.
# Eurytemora affinis is IMPORTANT for Prediction.
# Cyclops sp.  is IMPORTANT for Prediction.
# Nauplii Cyclopoida is NOT an important predictor. Discard Nauplii Cyclopoida from model.
# Nauplii Calanoida is NOT an important predictor. Discard Nauplii Calanoida from model.
# Thermocyclops oithonoides is IMPORTANT for Prediction.
# Eurytemora lacustris is IMPORTANT for Prediction.
# Ascomorpha saltans is NOT an important predictor. Discard Ascomorpha saltans from model.
# Asplanchna priodonta is NOT an important predictor. Discard Asplanchna priodonta from model.
# Brachionus angularis is NOT an important predictor. Discard Brachionus angularis from model.
# Brachionus calyciflorus calyciflorus is NOT an important predictor. Discard Brachionus calyciflorus calyciflorus from model.
# Brachionus calyciflorus f.amphiceros is NOT an important predictor. Discard Brachionus calyciflorus f.amphiceros from model.
# Brachionus calyciflorus spinosus is NOT an important predictor. Discard Brachionus calyciflorus spinosus from model.
# Brachionus urceolaris is NOT an important predictor. Discard Brachionus urceolaris from model.
# Brachionus calyciflorus f.anureiformis is NOT an important predictor. Discard Brachionus calyciflorus f.anureiformis from model.
# Filinia longiseta is NOT an important predictor. Discard Filinia longiseta from model.
# Keratella cochlearis cochlearis is IMPORTANT for Prediction.
# Keratella cochlearis f.tecta is IMPORTANT for Prediction.
# Keratella quadrata is NOT an important predictor. Discard Keratella quadrata from model.
# Polyarthra vulgaris is NOT an important predictor. Discard Polyarthra vulgaris from model.
# Polyarthra platyptera is NOT an important predictor. Discard Polyarthra platyptera from model.
# Pompholyx sp. is NOT an important predictor. Discard Pompholyx sp. from model.
# Synchaeta sp. is NOT an important predictor. Discard Synchaeta sp. from model.
# Trichocerca pusilla is NOT an important predictor. Discard Trichocerca pusilla from model.
# Trichocerca similis is NOT an important predictor. Discard Trichocerca similis from model.

# %%
outlier_list = []
for i in dftrain.columns:
  q1 = np.percentile(dftrain.loc[:, i], 25)
  q3 = np.percentile(dftrain.loc[:, i], 75)
  step = 1.5 * (q3-q1)
  print(f'Data points considered outliers for the feature {i}')

  outliers_rows = dftrain.loc[~((dftrain[i] >= q1 - step) & (dftrain[i] <= q3 + step)), :]
  outlier_list.append(list(outliers_rows.index))
  outliers = list(chain.from_iterable(outlier_list))

uniq_outlier = list(set(outliers))

dup_outliers = list(set([x for x in outliers if outliers.count(x) > 1]))
print('Outliers list:\n', uniq_outlier)
print('Length of outliers list:\n', len(uniq_outlier))

print('Duplicate list :\n', dup_outliers)
print('Length of duplicates list :\n', len(dup_outliers))

real_data = dftrain.drop(df.index[dup_outliers]).reset_index(drop=True)

print(real_data.shape)
# Out:
# Data points considered outliers for the feature PSU
# Data points considered outliers for the feature O2
# Data points considered outliers for the feature temp.
# Data points considered outliers for the feature SS
# Data points considered outliers for the feature SRP
# Data points considered outliers for the feature DOP
# Data points considered outliers for the feature PP
# Data points considered outliers for the feature NH4N
# Data points considered outliers for the feature NO3N
# Data points considered outliers for the feature DON
# Data points considered outliers for the feature PN
# Data points considered outliers for the feature TN/TP
# Data points considered outliers for the feature Fe
# Data points considered outliers for the feature SiO4Si
# Data points considered outliers for the feature DOC
# Data points considered outliers for the feature TPOC
# Data points considered outliers for the feature Windspeedinsitu
# Data points considered outliers for the feature DINtoDIP
# Data points considered outliers for the feature Cyanobacteria
# Data points considered outliers for the feature Chlorophyceae
# Data points considered outliers for the feature Euglenophyceae
# Data points considered outliers for the feature Diatomophyceae
# Data points considered outliers for the feature Flagellata
# Data points considered outliers for the feature Dinoflagellata
# Data points considered outliers for the feature Cryptophytes
# Data points considered outliers for the feature picophytoplankton
# Data points considered outliers for the feature Bosmina longirostris
# Data points considered outliers for the feature Ceriodaphnia sp.
# Data points considered outliers for the feature Diaphanosoma brachyurum
# Data points considered outliers for the feature Leptodora kindtii
# Data points considered outliers for the feature Acartia longiremis
# Data points considered outliers for the feature Acartia tonsa
# Data points considered outliers for the feature Eurytemora affinis
# Data points considered outliers for the feature Cyclops sp.
# Data points considered outliers for the feature Nauplii Cyclopoida
# Data points considered outliers for the feature Nauplii Calanoida
# Data points considered outliers for the feature Thermocyclops oithonoides
# Data points considered outliers for the feature Eurytemora lacustris
# Data points considered outliers for the feature Ascomorpha saltans
# Data points considered outliers for the feature Asplanchna priodonta
# Data points considered outliers for the feature Brachionus angularis
# Data points considered outliers for the feature Brachionus calyciflorus calyciflorus
# Data points considered outliers for the feature Brachionus calyciflorus f.amphiceros
# Data points considered outliers for the feature Brachionus calyciflorus spinosus
# Data points considered outliers for the feature Brachionus urceolaris
# Data points considered outliers for the feature Brachionus calyciflorus f.anureiformis
# Data points considered outliers for the feature Filinia longiseta
# Data points considered outliers for the feature Keratella cochlearis cochlearis
# Data points considered outliers for the feature Keratella cochlearis f.tecta
# Data points considered outliers for the feature Keratella quadrata
# Data points considered outliers for the feature Polyarthra vulgaris
# Data points considered outliers for the feature Polyarthra platyptera
# Data points considered outliers for the feature Pompholyx sp.
# Data points considered outliers for the feature Synchaeta sp.
# Data points considered outliers for the feature Trichocerca pusilla
# Data points considered outliers for the feature Trichocerca similis
# Data points considered outliers for the feature Depth
# Outliers list:
#  [0, 1, 2, 3, 4, 5, 6, 9, 10, 11, 12, 14, 20, 21, 23, 25, 28, 29, 31, 32, 34, 35, 36, 38, 39, 41, 42, 43, 46, 47, 48, 50, 52, 53, 55, 57, 58, 62, 63, 64, 65, 66, 67, 68, 69, 70, 72, 73, 74, 75, 76, 77, 78, 79, 81, 82, 84, 85, 87, 88, 91, 92, 97, 99, 100, 103, 104, 105, 109, 112, 113, 114, 115, 116, 117, 119, 120, 121, 122, 123, 124, 125, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 139, 140, 142, 143, 144, 145, 147, 148, 149, 150, 151, 154]
# Length of outliers list:
#  104
# Duplicate list :
#  [0, 1, 2, 4, 5, 6, 9, 10, 11, 12, 20, 21, 25, 28, 29, 31, 32, 35, 36, 38, 39, 41, 42, 43, 46, 47, 48, 52, 53, 55, 57, 58, 63, 64, 65, 66, 67, 68, 69, 70, 72, 73, 74, 75, 77, 78, 81, 82, 84, 85, 87, 88, 91, 92, 97, 99, 100, 103, 104, 105, 109, 112, 113, 114, 115, 116, 117, 119, 120, 121, 122, 123, 124, 125, 127, 128, 129, 130, 131, 133, 134, 135, 136, 139, 140, 142, 143, 144, 145, 147, 148, 149, 150, 151, 154]
# Length of duplicates list :
#  95
# (13, 57)
